# %%
print("Jupyter is working")
# Out:
# Jupyter is working

# %%
"""
# 🧪 Project Notebook Template
**Project Name:**  
**Author:**  
**Date:**  
**Description:**  

This notebook is part of the larger project and is intended for:
- Exploratory analysis  
- Testing ideas  
- Debugging  
- Notes and scratch work  

---

## 1. Environment & Setup

This section checks:
- Python version  
- Active virtual environment  
- Installed packages  

---
"""

import sys
import platform

print("Python version:", sys.version)
print("Platform:", platform.platform())

## 2. Imports
"""
Keep imports grouped and clean:
- Standard Library
- Third-party Libraries
- Local Modules (from your `tools`, `classes`, `utilities`, etc.)

---

# Standard library
import os
import sys
from pathlib import Path

# Third-party
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Local modules (adjust paths as needed)
PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

# Example:
# from tools.utilities import helpers

## 3. Project Paths

Define consistent paths so notebooks work no matter where you run them.

---
"""

# Define standard project paths
ROOT = Path.cwd().parent
DATA = ROOT / "data"
OUTPUTS = ROOT / "outputs"
NOTEBOOKS = ROOT / "notebooks"

DATA, OUTPUTS, NOTEBOOKS

## 4. Load Data
"""
Use this area to bring in:
- CSV files  
- APIs  
- Databases  
- Saved local objects  

---
"""

# Example of loading a CSV file (replace filename)
sample_file = DATA / "example.csv"

if sample_file.exists():
    df = pd.read_csv(sample_file)
    df.head()
else:
    print("No example.csv in data folder yet.")

## 5. Exploration / Scratch Work
"""
Use this area for quick tests, visualizations, logic experiments, etc.

(Don’t worry about code style here — move clean code into `.py` files later.)

---
"""

## 6. Supporting Functions
"""
If you write any helper functions during exploration, define them here.
Move them into your utilities/classes folder later.

---
"""

## 7. Results & Exports
"""
Save:
- data  
- charts  
- analysis summaries  

to your project's `/outputs` folder.

---
"""

output_file = OUTPUTS / "example_output.csv"

# Example save
# df.to_csv(output_file, index=False)

print("Would save to:", output_file)

## 8. Notes / Next Steps
"""
Document what you discovered, what needs to be done next, and what ideas should move into `.py` files.

---
"""
